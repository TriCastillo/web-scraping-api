# %% [markdown]
# # BILLBOARD (Web Scraping)

# %%
import requests # to connect with the website
import csv
from bs4 import BeautifulSoup # tool to gather data

def scrape_billboard_top10global():
    # Function to gather top 10 global charts

    # URL of the BILLBOARD Top 100 Global Songs
    url = 'https://www.billboard.com/charts/hot-100/'

    # Send request to gain access to the web
    # In return, web responds with the available data
    response = requests.get(url)

    # Check if request is successful "Response 200"
    if response.status_code == 200:
        # Parse (Filter) the HTML content using BeautifulSoup Library
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the div containing the music
        music_divs = soup.find_all('div', class_='o-chart-results-list-row-container')

        # Create an empty list to store the data
        charts = []
        # charts = [{song1: value, artist1: value}, ...]

        # Iterate over the top 10 song divs
        for index, div in enumerate(music_divs[:50], start=1):

            # Extract music title
            title = div.find('h3', class_='c-title').text.strip()

            # Extract artist name
            artist = div.find('span', attrs={'class': 'a-no-trucate'}).text.strip()

            # Create dictionary to store data
            music_details = {
                'title': title,
                'artist': artist
            }

            # Append latest data (music_details) to the list
            charts.append(music_details)
        return charts
    else:
        # If connection fails
        print("Error: Unable to retrieve data")
        return []

# Call the function
top_10_global_chart = scrape_billboard_top10global()

for index, music in enumerate(top_10_global_chart, start=1):
    print(f"Track {index}: ")
    print(f"Title: {music['title']}")
    print(f"Artist: {music['artist']}")
    print()

headers = ['Title', 'Artist']

# top_10_global_chart = scrape_billboard_top10global = charts = [{song1: value, artist1: value}, {song2: value, artist2: value}, ...]

with open('../data/billboard_top_charts.csv', 'w', encoding='utf-8') as file:
  writer = csv.writer(file)

  writer.writerow(headers)

  for i, song in enumerate(top_10_global_chart):
    title = song['title']
    artist = song['artist']

    writer.writerow([title, artist])
# Out:
# Track 1:
# Title: Golden
# Artist: HUNTR/X: EJAE, Audrey Nuna & REI AMI
#
# Track 2:
# Title: Ordinary
# Artist: Alex Warren
#
# Track 3:
# Title: Manchild
# Artist: Sabrina Carpenter
#
# Track 4:
# Title: What I Want
# Artist: Morgan Wallen Featuring Tate McRae
#
# Track 5:
# Title: Soda Pop
# Artist: Saja Boys: Andrew Choi, Neckwav, Danny Chung, Kevin Woo & samUIL Lee
#
# Track 6:
# Title: Your Idol
# Artist: Saja Boys: Andrew Choi, Neckwav, Danny Chung, Kevin Woo & samUIL Lee
#
# Track 7:
# Title: Love Me Not
# Artist: Ravyn Lenae
#
# Track 8:
# Title: Daisies
# Artist: Justin Bieber
#
# Track 9:
# Title: Lose Control
# Artist: Teddy Swims
#
# Track 10:
# Title: How It's Done
# Artist: HUNTR/X: EJAE, Audrey Nuna & REI AMI
#
# Track 11:
# Title: Die With A Smile
# Artist: Lady Gaga & Bruno Mars
#
# Track 12:
# Title: Tears
# Artist: Sabrina Carpenter
#
# Track 13:
# Title: I Got Better
# Artist: Morgan Wallen
#
# Track 14:
# Title: Mutt
# Artist: Leon Thomas
#
# Track 15:
# Title: A Bar Song (Tipsy)
# Artist: Shaboozey
#
# Track 16:
# Title: Beautiful Things
# Artist: Benson Boone
#
# Track 17:
# Title: Just In Case
# Artist: Morgan Wallen
#
# Track 18:
# Title: Undressed
# Artist: sombr
#
# Track 19:
# Title: What It Sounds Like
# Artist: HUNTR/X: EJAE, Audrey Nuna & REI AMI
#
# Track 20:
# Title: Good News
# Artist: Shaboozey
#
# Track 21:
# Title: I'm The Problem
# Artist: Morgan Wallen
#
# Track 22:
# Title: Pink Pony Club
# Artist: Chappell Roan
#
# Track 23:
# Title: Back To Friends
# Artist: sombr
#
# Track 24:
# Title: Takedown
# Artist: HUNTR/X: EJAE, Audrey Nuna & REI AMI
#
# Track 25:
# Title: Mystical Magical
# Artist: Benson Boone
#
# Track 26:
# Title: Luther
# Artist: Kendrick Lamar & SZA
#
# Track 27:
# Title: Free
# Artist: Rumi, JINU, EJAE & Andrew Choi
#
# Track 28:
# Title: Happen To Me
# Artist: Russell Dickerson
#
# Track 29:
# Title: Folded
# Artist: Kehlani
#
# Track 30:
# Title: Man I Need
# Artist: Olivia Dean
#
# Track 31:
# Title: When Did You Get Hot?
# Artist: Sabrina Carpenter
#
# Track 32:
# Title: Yukon
# Artist: Justin Bieber
#
# Track 33:
# Title: Burning Blue
# Artist: Mariah the Scientist
#
# Track 34:
# Title: It Depends
# Artist: Chris Brown Featuring Bryson Tiller
#
# Track 35:
# Title: All The Way
# Artist: BigXthaPlug Featuring Bailey Zimmerman
#
# Track 36:
# Title: Nobody's Son
# Artist: Sabrina Carpenter
#
# Track 37:
# Title: Sorry I'm Here For Someone Else
# Artist: Benson Boone
#
# Track 38:
# Title: Bottle Rockets
# Artist: Scotty McCreery & Hootie & The Blowfish
#
# Track 39:
# Title: No Broke Boys
# Artist: Disco Lines & Tinashe
#
# Track 40:
# Title: Somebody Loves Me
# Artist: PARTYNEXTDOOR, Drake & Cash Cobain
#
# Track 41:
# Title: 12 To 12
# Artist: sombr
#
# Track 42:
# Title: Worst Way
# Artist: Riley Green
#
# Track 43:
# Title: Bar None
# Artist: Jordan Davis
#
# Track 44:
# Title: The Dead Dance
# Artist: Lady Gaga
#
# Track 45:
# Title: Gabriela
# Artist: KATSEYE
#
# Track 46:
# Title: Revolving Door
# Artist: Tate McRae
#
# Track 47:
# Title: Back In The Saddle
# Artist: Luke Combs
#
# Track 48:
# Title: After All The Bars Are Closed
# Artist: Thomas Rhett
#
# Track 49:
# Title: Jealous Type
# Artist: Doja Cat
#
# Track 50:
# Title: House Tour
# Artist: Sabrina Carpenter

# %% [markdown]
# # General Popular YT Vid API

# %%
import requests
import csv

def get_top_10_music(api_key):
  """
  Gather The Top 10 Songs From YouTube Using The YouTubeAPIv3

  Args:
    api_key (str): Your Google Cloud API

  Returns:
    dict: Most recent top 10 music videos
  """
  # Base URL for the YouTubeAPIv3
  base_url = "https://www.googleapis.com/youtube/v3/videos"

  # Parameters for the API request
  params = {
      "part": "snippet", # Specifies video resouce properties that the API response will include
      "chart": "mostPopular", # Identifies the chart that you want to retrieve
      # "videoCategoryId": "10",
      "maxResults": 50,
      "key": api_key,
  }

  # Send GET request to the API
  response = requests.get(base_url, params=params)

  # Check if request was successful (status code 200)
  if response.status_code == 200:
    # Parse JSON response
    data = response.json()

    top_10_songs = []

    # Extract relevant music data
    for item in data.get("items", []):
      snippet = item.get("snippet", {})
      if (snippet):
        song = {
            "title": snippet.get("title", None),
            "channel": snippet.get("channelTitle", None),
            "link": f"https://www.youtube.com/watch?v={item['id']}"
        }
        top_10_songs.append(song)

    return top_10_songs
  else:
    # Print error message if request was unsuccessful
    print("Error: ", response.status_code)
    return None

# Use the provided API key
api_key = "Your_Google_Cloud_API_Key"

song_data = get_top_10_music(api_key)

# Iterate through the noted songs
for i, song in enumerate(song_data, start=1):
  print(f"Song {i}:")
  print(f"Title: {song['title']}")
  print(f"Channel: {song['channel']}")
  print(f"Link: {song['link']}")
  print()

headers = ['#', 'Title', 'Channel', 'Link']

with open('../data/youtube_top_charts.csv', 'w', encoding='utf-8') as file:
  writer = csv.writer(file)

  writer.writerow(headers)

  for i, song in enumerate(song_data, start=1):
    title = song['title']
    artist = song['channel']
    link = song['link']

    writer.writerow([i, title, artist, link])
# Out:
# Song 1:
# Title: Cardi B - Don't Do Too Much [Official Audio]
# Channel: Cardi B
# Link: https://www.youtube.com/watch?v=5-ueehJsBUI
#
# Song 2:
# Title: The Mandalorian and Grogu | Official Trailer | In Theaters May 22, 2026
# Channel: Star Wars
# Link: https://www.youtube.com/watch?v=_pa1KLXuW0Y
#
# Song 3:
# Title: Silent Hill f
# Channel: CoryxKenshin
# Link: https://www.youtube.com/watch?v=UnizX4fBVag
#
# Song 4:
# Title: Polo G - Chinatown Pt. 2 (Official Video)
# Channel: Polo G
# Link: https://www.youtube.com/watch?v=w31CUQrJJRQ
#
# Song 5:
# Title: IT: Welcome to Derry | Official Trailer | HBO Max
# Channel: HBO Max
# Link: https://www.youtube.com/watch?v=oKa6u7LT0qE
#
# Song 6:
# Title: TACO TUESDAY ADMIN ABUSE + New Brainrots!
# Channel: CaylusBlox
# Link: https://www.youtube.com/watch?v=sNA4aM4pm-0
#
# Song 7:
# Title: Babyfxce E - What Bag I'm In [Official Music Video]
# Channel: Babyfxce E
# Link: https://www.youtube.com/watch?v=YAyfFmUASaI
#
# Song 8:
# Title: Steel Ball Run JoJo's Bizarre Adventure Teaser Trailer
# Channel: Rotten Tomatoes TV
# Link: https://www.youtube.com/watch?v=UIwBcXV29aA
#
# Song 9:
# Title: SECRET Lucky Block Race In Steal A Brainrot..
# Channel: Foltyn
# Link: https://www.youtube.com/watch?v=mSX0Lp4CRls
#
# Song 10:
# Title: bbno$ - yezzir (official music video)
# Channel: bbno$
# Link: https://www.youtube.com/watch?v=oFP6tss8ODE
#
# Song 11:
# Title: The Bride! | Official Teaser
# Channel: Warner Bros.
# Link: https://www.youtube.com/watch?v=LJraZRHhFwQ
#
# Song 12:
# Title: 3 SCARY GAMES #109
# Channel: Markiplier
# Link: https://www.youtube.com/watch?v=FF5uEvoHa8s
#
# Song 13:
# Title: Zillionaire Doe - Skyami Living (Official Video)
# Channel: ZillionaireDoeVEVO
# Link: https://www.youtube.com/watch?v=r7bi8R_h5Sg
#
# Song 14:
# Title: OD - KNOCK Teaser Trailer - [ESRB] 4K
# Channel: KOJIMA PRODUCTIONS
# Link: https://www.youtube.com/watch?v=eHCqxLtwy5g
#
# Song 15:
# Title: I Upgraded My OWN BRAINROT…
# Channel: CashBlox
# Link: https://www.youtube.com/watch?v=PPX1rQ3dGZs
#
# Song 16:
# Title: Anonimus, Bryant Myers & Almighty: Toda La Vida (Video Oficial)
# Channel: Anonimus TV
# Link: https://www.youtube.com/watch?v=XjQowork5Mw
#
# Song 17:
# Title: Call of Duty: Black Ops 7 | Multiplayer Gameplay Reveal Trailer
# Channel: Call of Duty
# Link: https://www.youtube.com/watch?v=pGFYtZD53ZA
#
# Song 18:
# Title: Steal a Brainrot Admin Abuse (Taco Tuesday)
# Channel: KreekCraft
# Link: https://www.youtube.com/watch?v=jzfVFo5OB2Q
#
# Song 19:
# Title: Moon
# Channel: Daniel Caesar - Topic
# Link: https://www.youtube.com/watch?v=-JTRBQq_Ve8
#
# Song 20:
# Title: They Call Him OG Trailer - Pawan Kalyan | Emraan Hashmi | Sujeeth | Thaman S | DVV Danayya |
# Channel: DVV Entertainment
# Link: https://www.youtube.com/watch?v=_8J8LwoVH_0
#
# Song 21:
# Title: I Made The #1 CLAN in The World
# Channel: Jynxzi
# Link: https://www.youtube.com/watch?v=8wtOhmusT5I
#
# Song 22:
# Title: Sua Lo Mala'c (feat. Nineden, Dirtheedogg & Baka Jay)
# Channel: Gobby YT - Topic
# Link: https://www.youtube.com/watch?v=uh7AaPMv5yM
#
# Song 23:
# Title: Honest Trailers | Weapons
# Channel: Screen Junkies
# Link: https://www.youtube.com/watch?v=JX-FbcGhbtM
#
# Song 24:
# Title: A HOME INVASION Game, Based On A True Story
# Channel: berleezy
# Link: https://www.youtube.com/watch?v=FWSWymoAkQw
#
# Song 25:
# Title: C-Kan - Pordiosero (Video Oficial)
# Channel: ckan98
# Link: https://www.youtube.com/watch?v=ZgXv-ooUg-0
#
# Song 26:
# Title: STEEL BALL RUN Anime Trailer, VA Cast, Release Date!
# Channel: xForts
# Link: https://www.youtube.com/watch?v=io9try_-FoI
#
# Song 27:
# Title: HE GOT CAUGHT..
# Channel: Tyler & Snowi
# Link: https://www.youtube.com/watch?v=uCrn_U4PbrU
#
# Song 28:
# Title: Jarahn - Isa Noqu Lewa (Official Music Video) feat. Wilz
# Channel: Jarahn
# Link: https://www.youtube.com/watch?v=GHnc_O0CClk
#
# Song 29:
# Title: The Perfect Neighbor | Official Trailer | Netflix
# Channel: Netflix
# Link: https://www.youtube.com/watch?v=fNp85HGJtoo
#
# Song 30:
# Title: How Did I Get Here…
# Channel: CaseOh
# Link: https://www.youtube.com/watch?v=Ye8meSYPFM0
#
# Song 31:
# Title: 米津玄師, 宇多田ヒカル Kenshi Yonezu, Hikaru Utada -  JANE DOE
# Channel: Kenshi Yonezu  米津玄師
# Link: https://www.youtube.com/watch?v=sPLqsLsooJY
#
# Song 32:
# Title: Evernight Trailer — "Night Falls, Everyone, Close Your Eyes" | Honkai: Star Rail
# Channel: Honkai: Star Rail
# Link: https://www.youtube.com/watch?v=vh1ipA1aaUQ
#
# Song 33:
# Title: sammy deleted my brainrots.. 😭
# Channel: steak
# Link: https://www.youtube.com/watch?v=DTK5Uo_GKdE
#
# Song 34:
# Title: How Was I supposed to Know?
# Channel: Xania Monet - Topic
# Link: https://www.youtube.com/watch?v=emaSp37yESM
#
# Song 35:
# Title: AVENGERS DOOMSDAY FIRST LOOK 2026
# Channel: Emergency Awesome
# Link: https://www.youtube.com/watch?v=MqY14a7w6PI
#
# Song 36:
# Title: RANDOM Lucky Block Race in Minecraft
# Channel: SSundee
# Link: https://www.youtube.com/watch?v=JIlMBdr9NbU
#
# Song 37:
# Title: Pradabagshawty - Whoa (Official Music Video)
# Channel: Pradabagshawty
# Link: https://www.youtube.com/watch?v=WDbkERDYqo8
#
# Song 38:
# Title: Yakuza Kiwami 3 Trailer | RGG Summit 2025
# Channel: GameSpot
# Link: https://www.youtube.com/watch?v=GA5Lec9jYuQ
#
# Song 39:
# Title: Our Best Madden Game EVER! Wheel of MUT! Ep. #3
# Channel: MMG
# Link: https://www.youtube.com/watch?v=82bXnSBy36s
#
# Song 40:
# Title: The Neighbourhood - Sweater Weather (Lyrics)
# Channel: TrendingTracks
# Link: https://www.youtube.com/watch?v=LxCTdo-Sd_U
#
# Song 41:
# Title: IT: WELCOME TO DERRY Official Final Trailer (2025)
# Channel: KinoCheck.com
# Link: https://www.youtube.com/watch?v=ze2tNcBh5HE
#
# Song 42:
# Title: Chasing a Jackpot That’s Long Overdue
# Channel: Vegas Matt
# Link: https://www.youtube.com/watch?v=hZ939NhQpog
#
# Song 43:
# Title: Sexyy Red - Is You Coo (Official Music Video)
# Channel: Sexyy Red
# Link: https://www.youtube.com/watch?v=TwpdvOhFjgk
#
# Song 44:
# Title: Avengers: Doomsday (2026) - First Trailer | Robert Downey Jr.
# Channel: KH Studio
# Link: https://www.youtube.com/watch?v=gncCflgCRHU
#
# Song 45:
# Title: I Paid Streamers To Do Extreme Dares...
# Channel: Kai Cenat Live
# Link: https://www.youtube.com/watch?v=5UX8VbaxLzY
#
# Song 46:
# Title: Move On
# Channel: Kevin Powers - Topic
# Link: https://www.youtube.com/watch?v=hyJr_zC2GLE
#
# Song 47:
# Title: The Hand That Rocks the Cradle | Official Trailer | Hulu
# Channel: Hulu
# Link: https://www.youtube.com/watch?v=A0SFXzNMthc
#
# Song 48:
# Title: 2025 World Series of Poker Bracelet Event
# Channel: CBS Sports Network
# Link: https://www.youtube.com/watch?v=0WHJvOkJcXU
#
# Song 49:
# Title: OMB Peezy - STAY SOLID (official video)
# Channel: OMB Peezy
# Link: https://www.youtube.com/watch?v=f9jGVltB4ng
#
# Song 50:
# Title: Dead by Daylight: Sinister Grace – The Krasue Joins the Fog | Official Launch Trailer
# Channel: Dead by Daylight
# Link: https://www.youtube.com/watch?v=r8myRApJ_YI
