# %% [markdown]
# # BILLBOARD (Web Scraping)

# %%
import requests # to connect with the website
import csv
from bs4 import BeautifulSoup # tool to gather data

def scrape_billboard_top10global():
    # Function to gather top 10 global charts

    # URL of the BILLBOARD Top 100 Global Songs
    url = 'https://www.billboard.com/charts/hot-100/'

    # Send request to gain access to the web
    # In return, web responds with the available data
    response = requests.get(url)

    # Check if request is successful "Response 200"
    if response.status_code == 200:
        # Parse (Filter) the HTML content using BeautifulSoup Library
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the div containing the music
        music_divs = soup.find_all('div', class_='o-chart-results-list-row-container')

        # Create an empty list to store the data
        charts = []
        # charts = [{song1: value, artist1: value}, ...]

        # Iterate over the top 10 song divs
        for index, div in enumerate(music_divs[:50], start=1):

            # Extract music title
            title = div.find('h3', class_='c-title').text.strip()

            # Extract artist name
            artist = div.find('span', attrs={'class': 'a-no-trucate'}).text.strip()

            # Create dictionary to store data
            music_details = {
                'title': title,
                'artist': artist
            }

            # Append latest data (music_details) to the list
            charts.append(music_details)
        return charts
    else:
        # If connection fails
        print("Error: Unable to retrieve data")
        return []

# Call the function
top_10_global_chart = scrape_billboard_top10global()

for index, music in enumerate(top_10_global_chart, start=1):
    print(f"Track {index}: ")
    print(f"Title: {music['title']}")
    print(f"Artist: {music['artist']}")
    print()

headers = ['Title', 'Artist']

# top_10_global_chart = scrape_billboard_top10global = charts = [{song1: value, artist1: value}, {song2: value, artist2: value}, ...]

with open('billboard_top_cahrst.csv', 'w') as file:
  writer = csv.writer(file)

  writer.writerow(headers)

  for i, song in enumerate(top_10_global_chart):
    title = song['title']
    artist = song['artist']

    writer.writerow([title, artist])
# Out:
# Track 1:
# Title: Lovin On Me
# Artist: Jack Harlow
#
# Track 2:
# Title: Lose Control
# Artist: Teddy Swims
#
# Track 3:
# Title: Beautiful Things
# Artist: Benson Boone
#
# Track 4:
# Title: Cruel Summer
# Artist: Taylor Swift
#
# Track 5:
# Title: Snooze
# Artist: SZA
#
# Track 6:
# Title: I Remember Everything
# Artist: Zach Bryan Featuring Kacey Musgraves
#
# Track 7:
# Title: Greedy
# Artist: Tate McRae
#
# Track 8:
# Title: Fast Car
# Artist: Luke Combs
#
# Track 9:
# Title: Agora Hills
# Artist: Doja Cat
#
# Track 10:
# Title: Flowers
# Artist: Miley Cyrus
#
# Track 11:
# Title: Stick Season
# Artist: Noah Kahan
#
# Track 12:
# Title: Water
# Artist: Tyla
#
# Track 13:
# Title: Hiss
# Artist: Megan Thee Stallion
#
# Track 14:
# Title: Redrum
# Artist: 21 Savage
#
# Track 15:
# Title: Last Night
# Artist: Morgan Wallen
#
# Track 16:
# Title: Thinkin' Bout Me
# Artist: Morgan Wallen
#
# Track 17:
# Title: Paint The Town Red
# Artist: Doja Cat
#
# Track 18:
# Title: Is It Over Now? (Taylor's Version) [From The Vault]
# Artist: Taylor Swift
#
# Track 19:
# Title: Never Lose Me
# Artist: Flo Milli
#
# Track 20:
# Title: What Was I Made For?
# Artist: Billie Eilish
#
# Track 21:
# Title: Yes, And?
# Artist: Ariana Grande
#
# Track 22:
# Title: Houdini
# Artist: Dua Lipa
#
# Track 23:
# Title: Selfish
# Artist: Justin Timberlake
#
# Track 24:
# Title: Pretty Little Poison
# Artist: Warren Zeiders
#
# Track 25:
# Title: La Diabla
# Artist: Xavi
#
# Track 26:
# Title: Where The Wild Things Are
# Artist: Luke Combs
#
# Track 27:
# Title: Everybody
# Artist: Nicki Minaj Featuring Lil Uzi Vert
#
# Track 28:
# Title: Made For Me
# Artist: Muni Long
#
# Track 29:
# Title: Vampire
# Artist: Olivia Rodrigo
#
# Track 30:
# Title: The Painter
# Artist: Cody Johnson
#
# Track 31:
# Title: White Horse
# Artist: Chris Stapleton
#
# Track 32:
# Title: Rich Baby Daddy
# Artist: Drake Featuring Sexyy Red & SZA
#
# Track 33:
# Title: On My Mama
# Artist: Victoria Monet
#
# Track 34:
# Title: Exes
# Artist: Tate McRae
#
# Track 35:
# Title: Wild Ones
# Artist: Jessie Murph & Jelly Roll
#
# Track 36:
# Title: Feather
# Artist: Sabrina Carpenter
#
# Track 37:
# Title: Dance The Night
# Artist: Dua Lipa
#
# Track 38:
# Title: Bandit
# Artist: Don Toliver
#
# Track 39:
# Title: Need A Favor
# Artist: Jelly Roll
#
# Track 40:
# Title: Save Me
# Artist: Jelly Roll With Lainey Wilson
#
# Track 41:
# Title: Fukumean
# Artist: Gunna
#
# Track 42:
# Title: Fast Car
# Artist: Tracy Chapman
#
# Track 43:
# Title: Lil Boo Thang
# Artist: Paul Russell
#
# Track 44:
# Title: World On Fire
# Artist: Nate Smith
#
# Track 45:
# Title: Good Good
# Artist: Usher, Summer Walker & 21 Savage
#
# Track 46:
# Title: Truck Bed
# Artist: HARDY
#
# Track 47:
# Title: First Person Shooter
# Artist: Drake Featuring J. Cole
#
# Track 48:
# Title: Surround Sound
# Artist: JID Featuring 21 Savage & Baby Tate
#
# Track 49:
# Title: Strangers
# Artist: Kenya Grace
#
# Track 50:
# Title: My Love Mine All Mine
# Artist: Mitski

# %% [markdown]
# # General Popular YT Vid API

# %%
import requests
import csv

def get_top_10_music(api_key):
  """
  Gather The Top 10 Songs From YouTube Using The YouTubeAPIv3

  Args:
    api_key (str): Your Google Cloud API

  Returns:
    dict: Most recent top 10 music videos
  """
  # Base URL for the YouTubeAPIv3
  base_url = "https://www.googleapis.com/youtube/v3/videos"

  # Parameters for the API request
  params = {
      "part": "snippet", # Specifies video resouce properties that the API response will include
      "chart": "mostPopular", # Identifies the chart that you want to retrieve
      # "videoCategoryId": "10",
      "maxResults": 50,
      "key": api_key,
  }

  # Send GET request to the API
  response = requests.get(base_url, params=params)

  # Check if request was successful (status code 200)
  if response.status_code == 200:
    # Parse JSON response
    data = response.json()

    top_10_songs = []

    # Extract relevant music data
    for item in data.get("items", []):
      snippet = item.get("snippet", {})
      if (snippet):
        song = {
            "title": snippet.get("title", None),
            "channel": snippet.get("channelTitle", None),
            "link": f"https://www.youtube.com/watch?v={item['id']}"
        }
        top_10_songs.append(song)

    return top_10_songs
  else:
    # Print error message if request was unsuccessful
    print("Error: ", response.status_code)
    return None

# Use the provided API key
api_key = "Your_API_Key_Here"

song_data = get_top_10_music(api_key)

# Iterate through the noted songs
for i, song in enumerate(song_data, start=1):
  print(f"Song {i}:")
  print(f"Title: {song['title']}")
  print(f"Channel: {song['channel']}")
  print(f"Link: {song['link']}")
  print()

headers = ['#', 'Title', 'Channel', 'Link']

with open('youtube_top_charts.csv', 'w') as file:
  writer = csv.writer(file)

  writer.writerow(headers)

  for i, song in enumerate(song_data, start=1):
    title = song['title']
    artist = song['channel']
    link = song['link']

    writer.writerow([i, title, artist, link])
# Out:
# Song 1:
# Title: Marvel Animation's X-Men '97 | Official Trailer | Disney+
# Channel: Marvel Entertainment
# Link: https://www.youtube.com/watch?v=pv3Ss8o9gGQ
#
# Song 2:
# Title: Drake ft. Sexyy Red & SZA - Rich Baby Daddy (Official Music Video)
# Channel: DrakeVEVO
# Link: https://www.youtube.com/watch?v=UcsSdIXHCWM
#
# Song 3:
# Title: KAROL G, Tiësto - CONTIGO (Official Video)
# Channel: KarolGVEVO
# Link: https://www.youtube.com/watch?v=NCmp7AV8O9s
#
# Song 4:
# Title: Godzilla x Kong: The New Empire | Official Trailer 2
# Channel: Warner Bros. Pictures
# Link: https://www.youtube.com/watch?v=qqrpMRDuPfc
#
# Song 5:
# Title: College Football 25 | Official Teaser Trailer
# Channel: EA SPORTS College
# Link: https://www.youtube.com/watch?v=RvGlkQKipGo
#
# Song 6:
# Title: Updates on the Xbox Business | Official Xbox Podcast
# Channel: Xbox
# Link: https://www.youtube.com/watch?v=KGlD9SO3rKU
#
# Song 7:
# Title: Season 4, Episodes 4-6 Trailer
# Channel: The Chosen
# Link: https://www.youtube.com/watch?v=Bn_5uH5kUAU
#
# Song 8:
# Title: Chris Brown - Angel Numbers / Ten Toes (Official Video)
# Channel: ChrisBrownVEVO
# Link: https://www.youtube.com/watch?v=wWR0VD6qgt8
#
# Song 9:
# Title: ScHoolboy Q - Yeern 101 (Official Music Video)
# Channel: ScHoolBoyQVEVO
# Link: https://www.youtube.com/watch?v=0gG1UFrnGsE
#
# Song 10:
# Title: Chiefs Are Repeat Super Bowl Champs, Vegas Vacations and Wild After Parties | Ep 78
# Channel: New Heights
# Link: https://www.youtube.com/watch?v=8wt_Y5_MJ4o
#
# Song 11:
# Title: Lil Tecca, The Kid LAROI & Lil Skies - This My Life (Directed by Cole Bennett)
# Channel: Lyrical Lemonade
# Link: https://www.youtube.com/watch?v=h_7S4gLPZ34
#
# Song 12:
# Title: Oracle Red Bull Racing 2024 Season Launch
# Channel: Oracle Red Bull Racing
# Link: https://www.youtube.com/watch?v=qq2bItiq2WI
#
# Song 13:
# Title: The 9 Month Cruise Drama
# Channel: Chad Chad
# Link: https://www.youtube.com/watch?v=hxto08uuDRw
#
# Song 14:
# Title: 50 singles speed date in front of strangers | vs 1
# Channel: nectar
# Link: https://www.youtube.com/watch?v=vhYrLQ6pphs
#
# Song 15:
# Title: SIDEMEN MAFIA BUT THERE'S A MEDIC ROLE
# Channel: MoreSidemen
# Link: https://www.youtube.com/watch?v=udJ9EG1lAME
#
# Song 16:
# Title: skibidi toilet 70 (part 3)
# Channel: DaFuq!?Boom!
# Link: https://www.youtube.com/watch?v=QS01z1mkWYM
#
# Song 17:
# Title: Brent Faiyaz - WY@ [Official Music Video]
# Channel: Brent Faiyaz
# Link: https://www.youtube.com/watch?v=YjCtucn29JQ
#
# Song 18:
# Title: Rebuilding An Abandoned Porsche 911 Turbo In 24 Hours (Then Giving It Away)
# Channel: Tavarish
# Link: https://www.youtube.com/watch?v=nXyZFHVOEEw
#
# Song 19:
# Title: Sonic Superstars - Shadow Costume
# Channel: Sonic the Hedgehog
# Link: https://www.youtube.com/watch?v=wyZ_j9bTL3I
#
# Song 20:
# Title: BossMan Dlow - Get In With Me (Official Video)
# Channel: BossMan Dlow
# Link: https://www.youtube.com/watch?v=KmhAQJqOaIY
#
# Song 21:
# Title: Madame Web - SPOILER Talk!
# Channel: Jeremy Jahns
# Link: https://www.youtube.com/watch?v=r1i2DEEvYSw
#
# Song 22:
# Title: Lil Tjay - Good Life (Official Video)
# Channel: Lil Tjay
# Link: https://www.youtube.com/watch?v=eBTTO5_zdgU
#
# Song 23:
# Title: No Man's Sky: Omega Update Trailer
# Channel: HelloGamesTube
# Link: https://www.youtube.com/watch?v=EsBHl6kHFog
#
# Song 24:
# Title: HermitCraft S10 E03 - What Have I Done?!
# Channel: MCSkizzleman
# Link: https://www.youtube.com/watch?v=um7mSV4uNo8
#
# Song 25:
# Title: I BOUGHT THE CHEAPEST FERRARI IN THE WORLD- NEW PROJECT REVEAL
# Channel: Vin_ tra
# Link: https://www.youtube.com/watch?v=G1YYuYv1AP4
#
# Song 26:
# Title: THE MASKED MAN CAME BACK! ($50,000 ALL-STAR 1ON1'S)
# Channel: Deestroying
# Link: https://www.youtube.com/watch?v=Nhh3sYsiIyk
#
# Song 27:
# Title: Godzilla X Kong: The New Empire TRAILER 2 BREAKDOWN (IN DEPTH)
# Channel: DangerVille
# Link: https://www.youtube.com/watch?v=pITokqfk06k
#
# Song 28:
# Title: I’M PREGNANT!
# Channel: Keeley
# Link: https://www.youtube.com/watch?v=ERwMZZ-L1To
#
# Song 29:
# Title: Speedrunning to find a Girlfriend (in Infinite Craft)
# Channel: SmallAnt
# Link: https://www.youtube.com/watch?v=FN6X63jfzHk
#
# Song 30:
# Title: Bridgerton Season 3 | Official Clip | Netflix
# Channel: Netflix
# Link: https://www.youtube.com/watch?v=eKhh9VerYms
#
# Song 31:
# Title: Hermitcraft season 10 - Episode 3: Progress & Neighborhood Shenanigans!
# Channel: GoodTimesWithScar
# Link: https://www.youtube.com/watch?v=vJo4ZbXXlFI
#
# Song 32:
# Title: PSG vs. Real Sociedad: Extended Highlights | UCL Round of 16 1st Leg | CBS Sports Golazo
# Channel: CBS Sports Golazo
# Link: https://www.youtube.com/watch?v=zWvB6Wl6zx4
#
# Song 33:
# Title: HE GAVE UP?? LIKE THAT?  | Jujutsu Kaisen Chapter 251 Spoilers / Leaks
# Channel: Hundred
# Link: https://www.youtube.com/watch?v=KefUEZ0oPWc
#
# Song 34:
# Title: UV light kills viruses. Why isn't it everywhere?
# Channel: Vox
# Link: https://www.youtube.com/watch?v=_iTUaDp-FeI
#
# Song 35:
# Title: Mourinho Exclusive: Roma Exit | Rejecting Portugal + Saudi Jobs | Madrid vs Barcelona Rivalry Part 1
# Channel: Rio Ferdinand Presents FIVE
# Link: https://www.youtube.com/watch?v=2A17XoJAh7U
#
# Song 36:
# Title: SIDEMEN AMONG US BUT EVERYTHING IS DOUBLE SPEED!!!
# Channel: MoreSidemen
# Link: https://www.youtube.com/watch?v=nSI_2yvBAIU
#
# Song 37:
# Title: LE SSERAFIM (르세라핌) 'EASY' MV TEASER 1
# Channel: HYBE LABELS
# Link: https://www.youtube.com/watch?v=kE84TU1UljY
#
# Song 38:
# Title: Dime Si Tu - Yeri Mua X Jey F (Video oficial)
# Channel: Fullbrand Music
# Link: https://www.youtube.com/watch?v=Hn8iGjaNZi4
#
# Song 39:
# Title: GRUFF | Official Teaser | Righteous Robot
# Channel: Righteous Robot
# Link: https://www.youtube.com/watch?v=p7jSwfdDOXs
#
# Song 40:
# Title: Should Your Boyfriend Play Palworld?
# Channel: Girlfriend Reviews
# Link: https://www.youtube.com/watch?v=KQluXw_5bMk
#
# Song 41:
# Title: Madam Web - Angry Movie Review [WORST MOVIE OF 2024?!]
# Channel: AngryJoeShow
# Link: https://www.youtube.com/watch?v=y24MRQroiJs
#
# Song 42:
# Title: Fortnite OG Bronze to Unreal Speedrun!
# Channel: Lachlan
# Link: https://www.youtube.com/watch?v=vIopWHlYObQ
#
# Song 43:
# Title: DEADPOOL & WOLVERINE TRAILER: 20 MORE Easter Eggs We Missed!
# Channel: New Rockstars
# Link: https://www.youtube.com/watch?v=TbIdtKFdvlQ
#
# Song 44:
# Title: My favorite guy on instagram
# Channel: Drew Gooden
# Link: https://www.youtube.com/watch?v=GFAeAQ0qQ9c
#
# Song 45:
# Title: booktok & the hotgirlification of reading
# Channel: Mina Le
# Link: https://www.youtube.com/watch?v=WxDd8ocpcHk
#
# Song 46:
# Title: The Quiet Uber Driver | ft. @DarrylMayes
# Channel: Dtay Known
# Link: https://www.youtube.com/watch?v=wed70uB3aKE
#
# Song 47:
# Title: I forced Twitch Chat to fight in the American Revolution
# Channel: DougDoug
# Link: https://www.youtube.com/watch?v=XzwjCSQn8x8
#
# Song 48:
# Title: We Cast Ryan Trahan In Our Movie
# Channel: Sticks
# Link: https://www.youtube.com/watch?v=KK7K08dAtR4
#
# Song 49:
# Title: DEADPOOL & WOLVERINE TRAILER BREAKDOWN! Easter Eggs & Details You Missed!
# Channel: New Rockstars
# Link: https://www.youtube.com/watch?v=QkCD64x5BUA
#
# Song 50:
# Title: Overwatch 2 - EVERY HERO CHANGE for Season 9
# Channel: KarQ
# Link: https://www.youtube.com/watch?v=uQPFNRcoVHU
